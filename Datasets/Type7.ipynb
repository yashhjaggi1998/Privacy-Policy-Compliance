# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

tf.config.experimental.list_physical_devices('GPU')
# Out:
# Using TensorFlow backend.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Hyperparameters

vocab_size = 200
embedding_dim = 62
max_length = 50
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# %%
# Load Data

training_sentences = np.load("Datasets/Type7/training_sentences.npy")
testing_sentences = np.load("Datasets/Type7/testing_sentences.npy")
training_labels = np.load("Datasets/Type7/training_labels.npy")
testing_labels = np.load("Datasets/Type7/testing_labels.npy")

print(training_sentences.shape)
print(training_labels.shape)
print(testing_sentences.shape)
print(testing_labels.shape)
# Out:
# (20,)
# (20,)
# (7,)
# (7,)

# %%
# encode label values as integers

encoder = LabelEncoder()
encoder.fit(training_labels)
# convert integers to dummy variables (i.e. one hot encoded)
training_labels = np_utils.to_categorical(encoder.transform(training_labels))
testing_labels = np_utils.to_categorical(encoder.transform(testing_labels))

# %%
# Initialize Tokenizer

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'<OOV>': 1, 'the': 2, 'we': 3, 'under': 4, 'age': 5, 'of': 6, 'information': 7, '13': 8, 'that': 9, 'a': 10, 'if': 11, 'have': 12, 'children': 13, 'personal': 14, 'from': 15, 'or': 16, 'are': 17, 'platform': 18, 'account': 19, 'not': 20, 'collected': 21, 'on': 22, 'delete': 23, 'child': 24, 'to': 25, 'you': 26, 'in': 27, 'will': 28, 'and': 29, 'consent': 30, 'user': 31, 'is': 32, 'does': 33, 'collect': 34, 'become': 35, 'aware': 36, 'person': 37, 'without': 38, 'parental': 39, 'learn': 40, 'as': 41, 'even': 42, 'who': 43, 'so': 44, 'may': 45, 'an': 46, 'github': 47, 'any': 48, 'users': 49, 'knowingly': 50, 'otherwise': 51, 'directed': 52, 'at': 53, 'for': 54, 'has': 55, 'been': 56, 'this': 57, 'terminate': 58, 'relevant': 59, 'reason': 60, 'suspect': 61, 'cannot': 62, 'close': 63, 'content': 64, 'they': 65, 'until': 66, '18': 67, 'tiktok': 68, 'well': 69, 'event': 70, 'anyone': 71, 'provide': 72, 'separate': 73, 'experience': 74, 'younger': 75, 'united': 76, 'states': 77, 'take': 78, 'steps': 79, 'unless': 80, 'your': 81, 'automatically': 82, 'direct': 83, 'our': 84, 'california': 85, 'residents': 86, 'years': 87, 'request': 88, 'obtain': 89, 'removal': 90, 'posted': 91, 'by': 92, 'emailing': 93, 'us': 94, 'atprivacy': 95, 'com': 96, 'geeksforgeeks': 97, 'specifically': 98, 'about': 99, 'believes': 100, 'should': 101, 'get': 102, 'their': 103, 'parents': 104, 'before': 105, 'giving': 106, 'out': 107, 'also': 108, 'quickly': 109, 'possible': 110, 'do': 111, 'solicit': 112, 'living': 113, 'india': 114, 'allow': 115, 'such': 116, 'persons': 117, 'register': 118, 'allowed': 119, 'create': 120, 'use': 121, 'services': 122, 'although': 123, 'similar': 124, 'which': 125, 'only': 126, 'limited': 127}

# %%
# Tokenize the sentences

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# Sequential LSTM Model

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Pranav\.conda\envs\py37\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Pranav\.conda\envs\py37\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Pranav\.conda\envs\py37\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Pranav\.conda\envs\py37\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\Pranav\.conda\envs\py37\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 62)            12400
# _________________________________________________________________
# bidirectional (Bidirectional (None, 128)               65024
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 87,826
# Trainable params: 87,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set Training Parameters

num_epochs = 100
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

filepath = "Weights/Type7.hdf5"
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=1, callbacks = [checkpoint])
# Out:
# Train on 20 samples, validate on 7 samples
# WARNING:tensorflow:From C:\Users\Pranav\.conda\envs\py37\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
#
# Epoch 00001: val_acc improved from -inf to 0.57143, saving model to Weights/Type7.hdf5
# 20/20 [==============================] - 1s 71ms/sample - loss: 0.6933 - acc: 0.4500 - val_loss: 0.6931 - val_acc: 0.5714
# Epoch 2/100
#
# Epoch 00002: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.6917 - acc: 0.5500 - val_loss: 0.6935 - val_acc: 0.5714
# Epoch 3/100
#
# Epoch 00003: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6905 - acc: 0.5500 - val_loss: 0.6934 - val_acc: 0.5714
# Epoch 4/100
#
# Epoch 00004: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6895 - acc: 0.5500 - val_loss: 0.6941 - val_acc: 0.5714
# Epoch 5/100
#
# Epoch 00005: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6884 - acc: 0.5500 - val_loss: 0.6949 - val_acc: 0.5714
# Epoch 6/100
#
# Epoch 00006: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6870 - acc: 0.5500 - val_loss: 0.6951 - val_acc: 0.5714
# Epoch 7/100
#
# Epoch 00007: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6856 - acc: 0.5500 - val_loss: 0.6955 - val_acc: 0.5714
# Epoch 8/100
#
# Epoch 00008: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6841 - acc: 0.5500 - val_loss: 0.6967 - val_acc: 0.5714
# Epoch 9/100
#
# Epoch 00009: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6822 - acc: 0.5500 - val_loss: 0.6982 - val_acc: 0.5714
# Epoch 10/100
#
# Epoch 00010: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6802 - acc: 0.5500 - val_loss: 0.7000 - val_acc: 0.5714
# Epoch 11/100
#
# Epoch 00011: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6780 - acc: 0.5500 - val_loss: 0.7020 - val_acc: 0.5714
# Epoch 12/100
#
# Epoch 00012: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6753 - acc: 0.6000 - val_loss: 0.7045 - val_acc: 0.5714
# Epoch 13/100
#
# Epoch 00013: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6723 - acc: 0.6000 - val_loss: 0.7077 - val_acc: 0.4286
# Epoch 14/100
#
# Epoch 00014: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6688 - acc: 0.6000 - val_loss: 0.7114 - val_acc: 0.4286
# Epoch 15/100
#
# Epoch 00015: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6647 - acc: 0.6500 - val_loss: 0.7162 - val_acc: 0.4286
# Epoch 16/100
#
# Epoch 00016: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.6598 - acc: 0.6500 - val_loss: 0.7214 - val_acc: 0.4286
# Epoch 17/100
#
# Epoch 00017: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6543 - acc: 0.6500 - val_loss: 0.7272 - val_acc: 0.4286
# Epoch 18/100
#
# Epoch 00018: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6479 - acc: 0.6500 - val_loss: 0.7345 - val_acc: 0.4286
# Epoch 19/100
#
# Epoch 00019: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6403 - acc: 0.7000 - val_loss: 0.7439 - val_acc: 0.4286
# Epoch 20/100
#
# Epoch 00020: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6312 - acc: 0.8000 - val_loss: 0.7557 - val_acc: 0.2857
# Epoch 21/100
#
# Epoch 00021: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6201 - acc: 0.8000 - val_loss: 0.7708 - val_acc: 0.2857
# Epoch 22/100
#
# Epoch 00022: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.6064 - acc: 0.8000 - val_loss: 0.7911 - val_acc: 0.2857
# Epoch 23/100
#
# Epoch 00023: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.5893 - acc: 0.8000 - val_loss: 0.8191 - val_acc: 0.2857
# Epoch 24/100
#
# Epoch 00024: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.5688 - acc: 0.8500 - val_loss: 0.8580 - val_acc: 0.2857
# Epoch 25/100
#
# Epoch 00025: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.5433 - acc: 0.8500 - val_loss: 0.9115 - val_acc: 0.1429
# Epoch 26/100
#
# Epoch 00026: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.5112 - acc: 0.8500 - val_loss: 0.9914 - val_acc: 0.1429
# Epoch 27/100
#
# Epoch 00027: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.4733 - acc: 0.8500 - val_loss: 1.0995 - val_acc: 0.4286
# Epoch 28/100
#
# Epoch 00028: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.4475 - acc: 0.7000 - val_loss: 1.2346 - val_acc: 0.2857
# Epoch 29/100
#
# Epoch 00029: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.4320 - acc: 0.7500 - val_loss: 1.2808 - val_acc: 0.1429
# Epoch 30/100
#
# Epoch 00030: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.3666 - acc: 0.8500 - val_loss: 1.3692 - val_acc: 0.4286
# Epoch 31/100
#
# Epoch 00031: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.3593 - acc: 0.8500 - val_loss: 1.5616 - val_acc: 0.2857
# Epoch 32/100
#
# Epoch 00032: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.3370 - acc: 0.8500 - val_loss: 1.5582 - val_acc: 0.1429
# Epoch 33/100
#
# Epoch 00033: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.2685 - acc: 0.9000 - val_loss: 1.6309 - val_acc: 0.2857
# Epoch 34/100
#
# Epoch 00034: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.2654 - acc: 0.9000 - val_loss: 1.8567 - val_acc: 0.2857
# Epoch 35/100
#
# Epoch 00035: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.2224 - acc: 0.9000 - val_loss: 1.9029 - val_acc: 0.2857
# Epoch 36/100
#
# Epoch 00036: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.1809 - acc: 0.9500 - val_loss: 1.9424 - val_acc: 0.2857
# Epoch 37/100
#
# Epoch 00037: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.1784 - acc: 0.9500 - val_loss: 2.3125 - val_acc: 0.4286
# Epoch 38/100
#
# Epoch 00038: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.1726 - acc: 0.9000 - val_loss: 2.1403 - val_acc: 0.2857
# Epoch 39/100
#
# Epoch 00039: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.1890 - acc: 0.8500 - val_loss: 2.2161 - val_acc: 0.4286
# Epoch 40/100
#
# Epoch 00040: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0952 - acc: 1.0000 - val_loss: 2.5378 - val_acc: 0.5714
# Epoch 41/100
#
# Epoch 00041: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.1647 - acc: 0.9000 - val_loss: 2.2906 - val_acc: 0.2857
# Epoch 42/100
#
# Epoch 00042: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0926 - acc: 1.0000 - val_loss: 2.3485 - val_acc: 0.2857
# Epoch 43/100
# Epoch 00043: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.1263 - acc: 0.9000 - val_loss: 2.3559 - val_acc: 0.2857
# Epoch 44/100
#
# Epoch 00044: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0739 - acc: 1.0000 - val_loss: 2.4614 - val_acc: 0.5714
# Epoch 45/100
#
# Epoch 00045: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0815 - acc: 1.0000 - val_loss: 2.5521 - val_acc: 0.5714
# Epoch 46/100
#
# Epoch 00046: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0903 - acc: 1.0000 - val_loss: 2.5409 - val_acc: 0.4286
# Epoch 47/100
#
# Epoch 00047: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0575 - acc: 1.0000 - val_loss: 2.5631 - val_acc: 0.2857
# Epoch 48/100
#
# Epoch 00048: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0467 - acc: 1.0000 - val_loss: 2.6381 - val_acc: 0.2857
# Epoch 49/100
#
# Epoch 00049: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0525 - acc: 1.0000 - val_loss: 2.7086 - val_acc: 0.2857
# Epoch 50/100
#
# Epoch 00050: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0381 - acc: 1.0000 - val_loss: 2.8192 - val_acc: 0.4286
# Epoch 51/100
#
# Epoch 00051: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0217 - acc: 1.0000 - val_loss: 3.0136 - val_acc: 0.5714
# Epoch 52/100
#
# Epoch 00052: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0249 - acc: 1.0000 - val_loss: 3.1554 - val_acc: 0.5714
# Epoch 53/100
#
# Epoch 00053: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0275 - acc: 1.0000 - val_loss: 3.1447 - val_acc: 0.5714
# Epoch 54/100
#
# Epoch 00054: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0139 - acc: 1.0000 - val_loss: 3.0941 - val_acc: 0.4286
# Epoch 55/100
#
# Epoch 00055: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0089 - acc: 1.0000 - val_loss: 3.1046 - val_acc: 0.4286
# Epoch 56/100
#
# Epoch 00056: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0120 - acc: 1.0000 - val_loss: 3.1540 - val_acc: 0.4286
# Epoch 57/100
#
# Epoch 00057: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0118 - acc: 1.0000 - val_loss: 3.2328 - val_acc: 0.4286
# Epoch 58/100
#
# Epoch 00058: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0059 - acc: 1.0000 - val_loss: 3.3931 - val_acc: 0.5714
# Epoch 59/100
#
# Epoch 00059: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0032 - acc: 1.0000 - val_loss: 3.6008 - val_acc: 0.5714
# Epoch 60/100
#
# Epoch 00060: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0034 - acc: 1.0000 - val_loss: 3.7793 - val_acc: 0.5714
# Epoch 61/100
#
# Epoch 00061: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 0.0044 - acc: 1.0000 - val_loss: 3.8829 - val_acc: 0.5714
# Epoch 62/100
#
# Epoch 00062: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0043 - acc: 1.0000 - val_loss: 3.9088 - val_acc: 0.5714
# Epoch 63/100
#
# Epoch 00063: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0028 - acc: 1.0000 - val_loss: 3.8829 - val_acc: 0.5714
# Epoch 64/100
#
# Epoch 00064: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 10ms/sample - loss: 0.0016 - acc: 1.0000 - val_loss: 3.8218 - val_acc: 0.5714
# Epoch 65/100
#
# Epoch 00065: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 0.0010 - acc: 1.0000 - val_loss: 3.7477 - val_acc: 0.5714
# Epoch 66/100
#
# Epoch 00066: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 8.0298e-04 - acc: 1.0000 - val_loss: 3.6819 - val_acc: 0.5714
# Epoch 67/100
#
# Epoch 00067: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 7.8634e-04 - acc: 1.0000 - val_loss: 3.6357 - val_acc: 0.5714
# Epoch 68/100
#
# Epoch 00068: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 8.5025e-04 - acc: 1.0000 - val_loss: 3.6123 - val_acc: 0.5714
# Epoch 69/100
#
# Epoch 00069: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 9.3612e-04 - acc: 1.0000 - val_loss: 3.6078 - val_acc: 0.5714
# Epoch 70/100
#
# Epoch 00070: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 9.7150e-04 - acc: 1.0000 - val_loss: 3.6192 - val_acc: 0.5714
# Epoch 71/100
#
# Epoch 00071: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 9.1900e-04 - acc: 1.0000 - val_loss: 3.6442 - val_acc: 0.5714
# Epoch 72/100
#
# Epoch 00072: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 7.9129e-04 - acc: 1.0000 - val_loss: 3.6822 - val_acc: 0.5714
# Epoch 73/100
#
# Epoch 00073: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 6.3535e-04 - acc: 1.0000 - val_loss: 3.7326 - val_acc: 0.5714
# Epoch 74/100
#
# Epoch 00074: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 10ms/sample - loss: 4.9980e-04 - acc: 1.0000 - val_loss: 3.7927 - val_acc: 0.5714
# Epoch 75/100
#
# Epoch 00075: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 4.0744e-04 - acc: 1.0000 - val_loss: 3.8598 - val_acc: 0.5714
# Epoch 76/100
#
# Epoch 00076: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 3.4386e-04 - acc: 1.0000 - val_loss: 3.9317 - val_acc: 0.5714
# Epoch 77/100
#
# Epoch 00077: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 10ms/sample - loss: 3.0187e-04 - acc: 1.0000 - val_loss: 4.0056 - val_acc: 0.5714
# Epoch 78/100
#
# Epoch 00078: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.7476e-04 - acc: 1.0000 - val_loss: 4.0795 - val_acc: 0.5714
# Epoch 79/100
#
# Epoch 00079: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.5525e-04 - acc: 1.0000 - val_loss: 4.1504 - val_acc: 0.5714
# Epoch 80/100
#
# Epoch 00080: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.4242e-04 - acc: 1.0000 - val_loss: 4.2177 - val_acc: 0.5714
# Epoch 81/100
#
# Epoch 00081: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.3279e-04 - acc: 1.0000 - val_loss: 4.2811 - val_acc: 0.5714
# Epoch 82/100
#
# Epoch 00082: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.2538e-04 - acc: 1.0000 - val_loss: 4.3367 - val_acc: 0.5714
# Epoch 83/100
#
# Epoch 00083: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.1944e-04 - acc: 1.0000 - val_loss: 4.3864 - val_acc: 0.5714
# Epoch 84/100
#
# Epoch 00084: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.1453e-04 - acc: 1.0000 - val_loss: 4.4315 - val_acc: 0.5714
# Epoch 85/100
#
# Epoch 00085: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 10ms/sample - loss: 2.1034e-04 - acc: 1.0000 - val_loss: 4.4721 - val_acc: 0.5714
# Epoch 86/100
#
# Epoch 00086: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.0648e-04 - acc: 1.0000 - val_loss: 4.5067 - val_acc: 0.5714
# Epoch 87/100
#
# Epoch 00087: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 2.0280e-04 - acc: 1.0000 - val_loss: 4.5351 - val_acc: 0.5714
# Epoch 88/100
#
# Epoch 00088: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 1.9916e-04 - acc: 1.0000 - val_loss: 4.5589 - val_acc: 0.5714
# Epoch 89/100
#
# Epoch 00089: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.9547e-04 - acc: 1.0000 - val_loss: 4.5790 - val_acc: 0.5714
# Epoch 90/100
#
# Epoch 00090: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.9168e-04 - acc: 1.0000 - val_loss: 4.5955 - val_acc: 0.5714
# Epoch 91/100
#
# Epoch 00091: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 10ms/sample - loss: 1.8778e-04 - acc: 1.0000 - val_loss: 4.6088 - val_acc: 0.5714
# Epoch 92/100
#
# Epoch 00092: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.8375e-04 - acc: 1.0000 - val_loss: 4.6192 - val_acc: 0.5714
# Epoch 93/100
#
# Epoch 00093: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 1.7959e-04 - acc: 1.0000 - val_loss: 4.6271 - val_acc: 0.5714
# Epoch 94/100
#
# Epoch 00094: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.7537e-04 - acc: 1.0000 - val_loss: 4.6328 - val_acc: 0.5714
# Epoch 95/100
#
# Epoch 00095: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.7109e-04 - acc: 1.0000 - val_loss: 4.6363 - val_acc: 0.5714
# Epoch 96/100
#
# Epoch 00096: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.6682e-04 - acc: 1.0000 - val_loss: 4.6378 - val_acc: 0.5714
# Epoch 97/100
#
# Epoch 00097: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.6267e-04 - acc: 1.0000 - val_loss: 4.6375 - val_acc: 0.5714
# Epoch 98/100
#
# Epoch 00098: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.5857e-04 - acc: 1.0000 - val_loss: 4.6354 - val_acc: 0.5714
# Epoch 99/100
#
# Epoch 00099: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 9ms/sample - loss: 1.5459e-04 - acc: 1.0000 - val_loss: 4.6314 - val_acc: 0.5714
# Epoch 100/100
#
# Epoch 00100: val_acc did not improve from 0.57143
# 20/20 [==============================] - 0s 8ms/sample - loss: 1.5073e-04 - acc: 1.0000 - val_loss: 4.6262 - val_acc: 0.5714

# %%
avg = 0

for i in range(len(training_sequences)):
    avg = avg + len(training_sequences[i])
    
print(avg/(len(training_sequences)))
# Out:
# 24.55

# %%
# Finding the longest sentence overall (Ignore the error)

mini = 0
index = 0
indextest = 0
for i in range(len(training_sequences)):
    if len(training_sequences[i]) > mini:
        mini = len(training_sequences[i])
        index = i
        
for i in range(len(testing_sequences)):
    if len(testing_sequences[i]) > mini:
        mini = len(testing_sequences[i])
        indextest = i

print(mini)
print(index)
print(training_sentences[index])
print("\n")
print(testing_sentences[indextest])
# Out:
# 36
# 7
# Even if we become aware that personal information has been collected on the Platform from a person under the age of 13, we cannot delete this information and terminate the account until the person does so.
#
#
# Children under the age of 13 are not allowed to create an account or otherwise use the Services.

# %%
# if input() == "yes":
#     model.save("Weights/Type7_LSTM.h5")

# %%
# Load the previously saved weights
model = tf.keras.models.load_model("Weights/Type7.hdf5")
# Re-evaluate the model
loss, acc = model.evaluate(testing_padded, testing_labels, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 7/7 - 0s - loss: 0.6931 - acc: 0.5714
# Restored model, accuracy: 57.14%

# %%
if input() == "yes":
    model.save("Weights/Type7_{:5.2f}.hdf5".format(100 * acc))
# Out:
# no
